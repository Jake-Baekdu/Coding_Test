# %% [markdown]
# # 문제 설명
#
# ### 문제 설명
# 정수 n을 입력받아 n의 약수를 모두 더한 값을 리턴하는 함수, solution을 완성해주세요.
#
# ### 제한 조건
#
# n은 0 이상 3000이하인 정수입니다.
#
# ### 입출력 예
# 입출력 예 #1
# 12의 약수는 1, 2, 3, 4, 6, 12입니다. 이를 모두 더하면 28입니다.
#
# 입출력 예 #2
# 5의 약수는 1, 5입니다. 이를 모두 더하면 6입니다.
# ![image.png](attachment:image.png)
#
#
# 출처  :  https://programmers.co.kr/learn/courses/30/lessons/12928?language=python3

# %%
def solution(n):
    result = [i for i in range(1, n+1) if n % i == 0]
    return sum(result)

# %%
solution(12)
# Out:
# 28

# %% [markdown]
# ## 풀이 후기
#
# 리스트컨프리헨션이 머리 속에 딱 떠올라서 한번 시도해보았다. 코테준비를 하면서  실제로 적용해본거는 처음인듯..

# %% [markdown]
# ## 다른 풀이

# %%
def sumDivisor(num):
    return sum(filter(lambda x: num % x == 0, range(1, num + 1)))

# 아래는 테스트로 출력해 보기 위한 코드입니다.
print(sumDivisor(12))
# Out:
# 28

# %% [markdown]
# ### sum함수 안에 filter를 넣어서 lambda를 써서 해결한 풀이다. 조금 복잡해 보이지만 filter와 lambda를 유용하게 사용한 풀이인 것 같다.
