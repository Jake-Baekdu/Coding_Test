# %%
def compress(text, tok_len):
    words = [text[i:i+tok_len] for i in range(0, len(text), tok_len)]
    res = []
    cur_word = words[0]
    cur_cnt = 1
    for a, b in zip(words, words[1:] + ['']):
        if a == b:
            cur_cnt += 1
        else:
            res.append([cur_word, cur_cnt])
            cur_word = b
            cur_cnt = 1
        print(a,b)
        print("카운트 : ", cur_cnt)
    print(res)
    return sum(len(word) + (len(str(cnt)) if cnt > 1 else 0) for word, cnt in res)

def solution(text):
    return min(compress(text, tok_len) for tok_len in list(range(1, int(len(text)/2) + 1)) + [len(text)])

a = [
    "aabbaccc",
    "ababcdcdababcdcd",
    "abcabcdede",
    "abcabcabcabcdededededede",
    "xababcdcdababcdcd",

    'aaaaaa',
]

for x in a:
    print(solution(x))
# Out:
# a a
# 카운트 :  2
# a b
# 카운트 :  1
# b b
# 카운트 :  2
# b a
# 카운트 :  1
# a c
# 카운트 :  1
# c c
# 카운트 :  2
# c c
# 카운트 :  3
# c
# 카운트 :  1
# [['a', 2], ['b', 2], ['a', 1], ['c', 3]]
# aa bb
# 카운트 :  1
# bb ac
# 카운트 :  1
# ac cc
# 카운트 :  1
# cc
# 카운트 :  1
# [['aa', 1], ['bb', 1], ['ac', 1], ['cc', 1]]
# aab bac
# 카운트 :  1
# bac cc
# 카운트 :  1
# cc
# 카운트 :  1
# [['aab', 1], ['bac', 1], ['cc', 1]]
# aabb accc
# 카운트 :  1
# accc
# 카운트 :  1
# [['aabb', 1], ['accc', 1]]
# aabbaccc
# 카운트 :  1
# [['aabbaccc', 1]]
# 7
# a b
# 카운트 :  1
# b a
# 카운트 :  1
# a b
# 카운트 :  1
# b c
# 카운트 :  1
# c d
# 카운트 :  1
# d c
# 카운트 :  1
# c d
# 카운트 :  1
# d a
# 카운트 :  1
# a b
# 카운트 :  1
# b a
# 카운트 :  1
# a b
# 카운트 :  1
# b c
# 카운트 :  1
# c d
# 카운트 :  1
# d c
# 카운트 :  1
# c d
# 카운트 :  1
# d
# 카운트 :  1
# [['a', 1], ['b', 1], ['a', 1], ['b', 1], ['c', 1], ['d', 1], ['c', 1], ['d', 1], ['a', 1], ['b', 1], ['a', 1], ['b', 1], ['c', 1], ['d', 1], ['c', 1], ['d', 1]]
# ab ab
# 카운트 :  2
# ab cd
# 카운트 :  1
# cd cd
# 카운트 :  2
# cd ab
# 카운트 :  1
# ab ab
# 카운트 :  2
# ab cd
# 카운트 :  1
# cd cd
# 카운트 :  2
# cd
# 카운트 :  1
# [['ab', 2], ['cd', 2], ['ab', 2], ['cd', 2]]
# aba bcd
# 카운트 :  1
# bcd cda
# 카운트 :  1
# cda bab
# 카운트 :  1
# bab cdc
# 카운트 :  1
# cdc d
# 카운트 :  1
# d
# 카운트 :  1
# [['aba', 1], ['bcd', 1], ['cda', 1], ['bab', 1], ['cdc', 1], ['d', 1]]
# abab cdcd
# 카운트 :  1
# cdcd abab
# 카운트 :  1
# abab cdcd
# 카운트 :  1
# cdcd
# 카운트 :  1
# [['abab', 1], ['cdcd', 1], ['abab', 1], ['cdcd', 1]]
# ababc dcdab
# 카운트 :  1
# dcdab abcdc
# 카운트 :  1
# abcdc d
# 카운트 :  1
# d
# 카운트 :  1
# [['ababc', 1], ['dcdab', 1], ['abcdc', 1], ['d', 1]]
# ababcd cdabab
# 카운트 :  1
# cdabab cdcd
# 카운트 :  1
# cdcd
# 카운트 :  1
# [['ababcd', 1], ['cdabab', 1], ['cdcd', 1]]
# ababcdc dababcd
# 카운트 :  1
# dababcd cd
# 카운트 :  1
# cd
# 카운트 :  1
# [['ababcdc', 1], ['dababcd', 1], ['cd', 1]]
# ababcdcd ababcdcd
# 카운트 :  2
# ababcdcd
# 카운트 :  1
# [['ababcdcd', 2]]
# ababcdcdababcdcd
# 카운트 :  1
# [['ababcdcdababcdcd', 1]]
# 9
# a b
# 카운트 :  1
# b c
# 카운트 :  1
# c a
# 카운트 :  1
# a b
# 카운트 :  1
# b c
# 카운트 :  1
# c d
# 카운트 :  1
# d e
# 카운트 :  1
# e d
# 카운트 :  1
# d e
# 카운트 :  1
# e
# 카운트 :  1
# [['a', 1], ['b', 1], ['c', 1], ['a', 1], ['b', 1], ['c', 1], ['d', 1], ['e', 1], ['d', 1], ['e', 1]]
# ab ca
# 카운트 :  1
# ca bc
# 카운트 :  1
# bc de
# 카운트 :  1
# de de
# 카운트 :  2
# de
# 카운트 :  1
# [['ab', 1], ['ca', 1], ['bc', 1], ['de', 2]]
# abc abc
# 카운트 :  2
# abc ded
# 카운트 :  1
# ded e
# 카운트 :  1
# e
# 카운트 :  1
# [['abc', 2], ['ded', 1], ['e', 1]]
# abca bcde
# 카운트 :  1
# bcde de
# 카운트 :  1
# de
# 카운트 :  1
# [['abca', 1], ['bcde', 1], ['de', 1]]
# abcab cdede
# 카운트 :  1
# cdede
# 카운트 :  1
# [['abcab', 1], ['cdede', 1]]
# abcabcdede
# 카운트 :  1
# [['abcabcdede', 1]]
# 8
# a b
# 카운트 :  1
# b c
# 카운트 :  1
# c a
# 카운트 :  1
# a b
# 카운트 :  1
# b c
# 카운트 :  1
# c a
# 카운트 :  1
# a b
# 카운트 :  1
# b c
# 카운트 :  1
# c a
# 카운트 :  1
# a b
# 카운트 :  1
# b c
# 카운트 :  1
# c d
# 카운트 :  1
# d e
# 카운트 :  1
# e d
# 카운트 :  1
# d e
# 카운트 :  1
# e d
# 카운트 :  1
# d e
# 카운트 :  1
# e d
# 카운트 :  1
# d e
# 카운트 :  1
# e d
# 카운트 :  1
# d e
# 카운트 :  1
# e d
# 카운트 :  1
# d e
# 카운트 :  1
# e
# 카운트 :  1
# [['a', 1], ['b', 1], ['c', 1], ['a', 1], ['b', 1], ['c', 1], ['a', 1], ['b', 1], ['c', 1], ['a', 1], ['b', 1], ['c', 1], ['d', 1], ['e', 1], ['d', 1], ['e', 1], ['d', 1], ['e', 1], ['d', 1], ['e', 1], ['d', 1], ['e', 1], ['d', 1], ['e', 1]]
# ab ca
# 카운트 :  1
# ca bc
# 카운트 :  1
# bc ab
# 카운트 :  1
# ab ca
# 카운트 :  1
# ca bc
# 카운트 :  1
# bc de
# 카운트 :  1
# de de
# 카운트 :  2
# de de
# 카운트 :  3
# de de
# 카운트 :  4
# de de
# 카운트 :  5
# de de
# 카운트 :  6
# de
# 카운트 :  1
# [['ab', 1], ['ca', 1], ['bc', 1], ['ab', 1], ['ca', 1], ['bc', 1], ['de', 6]]
# abc abc
# 카운트 :  2
# abc abc
# 카운트 :  3
# abc abc
# 카운트 :  4
# abc ded
# 카운트 :  1
# ded ede
# 카운트 :  1
# ede ded
# 카운트 :  1
# ded ede
# 카운트 :  1
# ede
# 카운트 :  1
# [['abc', 4], ['ded', 1], ['ede', 1], ['ded', 1], ['ede', 1]]
# abca bcab
# 카운트 :  1
# bcab cabc
# 카운트 :  1
# cabc dede
# 카운트 :  1
# dede dede
# 카운트 :  2
# dede dede
# 카운트 :  3
# dede
# 카운트 :  1
# [['abca', 1], ['bcab', 1], ['cabc', 1], ['dede', 3]]
# abcab cabca
# 카운트 :  1
# cabca bcded
# 카운트 :  1
# bcded edede
# 카운트 :  1
# edede dede
# 카운트 :  1
# dede
# 카운트 :  1
# [['abcab', 1], ['cabca', 1], ['bcded', 1], ['edede', 1], ['dede', 1]]
# abcabc abcabc
# 카운트 :  2
# abcabc dedede
# 카운트 :  1
# dedede dedede
# 카운트 :  2
# dedede
# 카운트 :  1
# [['abcabc', 2], ['dedede', 2]]
# abcabca bcabcde
# 카운트 :  1
# bcabcde dededed
# 카운트 :  1
# dededed ede
# 카운트 :  1
# ede
# 카운트 :  1
# [['abcabca', 1], ['bcabcde', 1], ['dededed', 1], ['ede', 1]]
# abcabcab cabcdede
# 카운트 :  1
# cabcdede dededede
# 카운트 :  1
# dededede
# 카운트 :  1
# [['abcabcab', 1], ['cabcdede', 1], ['dededede', 1]]
# abcabcabc abcdedede
# 카운트 :  1
# abcdedede dedede
# 카운트 :  1
# dedede
# 카운트 :  1
# [['abcabcabc', 1], ['abcdedede', 1], ['dedede', 1]]
# abcabcabca bcdededede
# 카운트 :  1
# bcdededede dede
# 카운트 :  1
# dede
# 카운트 :  1
# [['abcabcabca', 1], ['bcdededede', 1], ['dede', 1]]
# abcabcabcab cdedededede
# 카운트 :  1
# cdedededede de
# 카운트 :  1
# de
# 카운트 :  1
# [['abcabcabcab', 1], ['cdedededede', 1], ['de', 1]]
# abcabcabcabc dededededede
# 카운트 :  1
# dededededede
# 카운트 :  1
# [['abcabcabcabc', 1], ['dededededede', 1]]
# abcabcabcabcdededededede
# 카운트 :  1
# [['abcabcabcabcdededededede', 1]]
# 14
# x a
# 카운트 :  1
# a b
# 카운트 :  1
# b a
# 카운트 :  1
# a b
# 카운트 :  1
# b c
# 카운트 :  1
# c d
# 카운트 :  1
# d c
# 카운트 :  1
# c d
# 카운트 :  1
# d a
# 카운트 :  1
# a b
# 카운트 :  1
# b a
# 카운트 :  1
# a b
# 카운트 :  1
# b c
# 카운트 :  1
# c d
# 카운트 :  1
# d c
# 카운트 :  1
# c d
# 카운트 :  1
# d
# 카운트 :  1
# [['x', 1], ['a', 1], ['b', 1], ['a', 1], ['b', 1], ['c', 1], ['d', 1], ['c', 1], ['d', 1], ['a', 1], ['b', 1], ['a', 1], ['b', 1], ['c', 1], ['d', 1], ['c', 1], ['d', 1]]
# xa ba
# 카운트 :  1
# ba bc
# 카운트 :  1
# bc dc
# 카운트 :  1
# dc da
# 카운트 :  1
# da ba
# 카운트 :  1
# ba bc
# 카운트 :  1
# bc dc
# 카운트 :  1
# dc d
# 카운트 :  1
# d
# 카운트 :  1
# [['xa', 1], ['ba', 1], ['bc', 1], ['dc', 1], ['da', 1], ['ba', 1], ['bc', 1], ['dc', 1], ['d', 1]]
# xab abc
# 카운트 :  1
# abc dcd
# 카운트 :  1
# dcd aba
# 카운트 :  1
# aba bcd
# 카운트 :  1
# bcd cd
# 카운트 :  1
# cd
# 카운트 :  1
# [['xab', 1], ['abc', 1], ['dcd', 1], ['aba', 1], ['bcd', 1], ['cd', 1]]
# xaba bcdc
# 카운트 :  1
# bcdc daba
# 카운트 :  1
# daba bcdc
# 카운트 :  1
# bcdc d
# 카운트 :  1
# d
# 카운트 :  1
# [['xaba', 1], ['bcdc', 1], ['daba', 1], ['bcdc', 1], ['d', 1]]
# xabab cdcda
# 카운트 :  1
# cdcda babcd
# 카운트 :  1
# babcd cd
# 카운트 :  1
# cd
# 카운트 :  1
# [['xabab', 1], ['cdcda', 1], ['babcd', 1], ['cd', 1]]
# xababc dcdaba
# 카운트 :  1
# dcdaba bcdcd
# 카운트 :  1
# bcdcd
# 카운트 :  1
# [['xababc', 1], ['dcdaba', 1], ['bcdcd', 1]]
# xababcd cdababc
# 카운트 :  1
# cdababc dcd
# 카운트 :  1
# dcd
# 카운트 :  1
# [['xababcd', 1], ['cdababc', 1], ['dcd', 1]]
# xababcdc dababcdc
# 카운트 :  1
# dababcdc d
# 카운트 :  1
# d
# 카운트 :  1
# [['xababcdc', 1], ['dababcdc', 1], ['d', 1]]
# xababcdcdababcdcd
# 카운트 :  1
# [['xababcdcdababcdcd', 1]]
# 17
# a a
# 카운트 :  2
# a a
# 카운트 :  3
# a a
# 카운트 :  4
# a a
# 카운트 :  5
# a a
# 카운트 :  6
# a
# 카운트 :  1
# [['a', 6]]
# aa aa
# 카운트 :  2
# aa aa
# 카운트 :  3
# aa
# 카운트 :  1
# [['aa', 3]]
# aaa aaa
# 카운트 :  2
# aaa
# 카운트 :  1
# [['aaa', 2]]
# aaaaaa
# 카운트 :  1
# [['aaaaaa', 1]]
# 2

# %%
def solution2(s):
    answer = len(s)
    for x in range(1, int(len(s)/2)+1):
        d = 0
        comp = ''
        c = 1
        for i in range(0, len(s), x):
            temp = s[i:i+x]
#             print(x, i)
#             print(comp, temp)
            if comp == temp:
                c += 1
            elif comp != temp :
                d += len(temp)
                if c > 1 :
                    d += len(str(c))
                c = 1
                comp = temp

        if c > 1:
            d += len(str(c))
        answer = min(answer, d)
    return answer

a = [
    "aabbaccc",
    "ababcdcdababcdcd",
    "abcabcdede",
    "abcabcabcabcdededededede",
    "xababcdcdababcdcd",

    'aaaaaa',
]

for x in a:
    print(solution2(x))
# Out:
# 7
# 9
# 8
# 14
# 17
# 2

# %%
def solution3(s):
    if len(s) == 0 or len(s) == 1:
        return len(s)
    answer = len(s)
    for l in range(1, len(s)//2 + 1):
        last = (1, "")
        temp = ""
        for i in range(0, len(s), l):
            t = s[i:i+l]
            if t == last[1]:
                last = (last[0] + 1, t)
            else:
                if last[0] != 0:
                    temp += "%d%s" % last if last[0] > 1 else last[1]
                last = (1, t)
        if last[0] > 0:
            temp += "%d%s" % last if last[0] > 1 else last[1]
        answer = min(answer , len(temp))
    return answer

a = [
    "aabbaccc",
    "ababcdcdababcdcd",
    "abcabcdede",
    "abcabcabcabcdededededede",
    "xababcdcdababcdcd",

    'aaaaaa',
]

for x in a:
    print(solution3(x))
# Out:
# 7
# 9
# 8
# 14
# 17
# 2

# %%
last = (0, "aa")
a = "%d%s" % last if last[0] > 1 else last[1]
print(a)
# Out:
# aa
