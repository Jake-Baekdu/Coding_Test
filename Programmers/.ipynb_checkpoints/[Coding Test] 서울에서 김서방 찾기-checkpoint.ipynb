# %% [markdown]
# # 문제설명
#
#
# ![image.png](attachment:image.png)

# %%
def solution(seoul):
    num = seoul.index("Kim")
    result = print("\"김서방은 %d에 있다\""%num)
    return result

# %% [markdown]
# # 풀이 후기
#
# 처음에 리턴값에 print를 넣었더니 결과값은 기대값과 똑같이 나오는데 계속 오류가 떴다. print로 넣으면 리턴할 때 아무래도 string이 아닌 그냥 프린트 값으로 나오는건지.... 정확한 이유는 모르겠지만 str 그대로 리턴해주는것이 정답이었다.
