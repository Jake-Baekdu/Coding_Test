# %%
num = input()
cnt = 0
changedNum = num
if num == '0':
    print(1)
else:
    while(True):
        tmp = sum(list(map(int, changedNum)))
        changedNum = changedNum[-1] + str(tmp)[-1]
        print(cnt, tmp, changedNum)
        cnt += 1
        if num == changedNum:
            print(cnt)
            break
# Out:
# 1
# 0 1 11
# 1 2 12
# 2 3 23
# 3 5 35
# 4 8 58
# 5 13 83
# 6 11 31
# 7 4 14
# 8 5 45
# 9 9 59
# 10 14 94
# 11 13 43
# 12 7 37
# 13 10 70
# 14 7 07
# 15 7 77
# 16 14 74
# 17 11 41
# 18 5 15
# 19 6 56
# 20 11 61
# 21 7 17
# 22 8 78
# 23 15 85
# 24 13 53
# 25 8 38
# 26 11 81
# 27 9 19
# 28 10 90
# 29 9 09
# 30 9 99
# 31 18 98
# 32 17 87
# 33 15 75
# 34 12 52
# 35 7 27
# 36 9 79
# 37 16 96
# 38 15 65
# 39 11 51
# 40 6 16
# 41 7 67
# 42 13 73
# 43 10 30
# 44 3 03
# 45 3 33
# 46 6 36
# 47 9 69
# 48 15 95
# 49 14 54
# 50 9 49
# 51 13 93
# 52 12 32
# 53 5 25
# 54 7 57
# 55 12 72
# 56 9 29
# 57 11 91
# 58 10 10
# 59 1 01
# 60 1 11
# 61 2 12
# 62 3 23
# 63 5 35
# 64 8 58
# 65 13 83
# 66 11 31
# 67 4 14
# 68 5 45
# 69 9 59
# 70 14 94
# 71 13 43
# 72 7 37
# 73 10 70
# 74 7 07
# 75 7 77
# 76 14 74
# 77 11 41
# 78 5 15
# 79 6 56
# 80 11 61
# 81 7 17
# 82 8 78
# 83 15 85
# 84 13 53
# 85 8 38
# 86 11 81
# 87 9 19
# 88 10 90
# 89 9 09
# 90 9 99
# 91 18 98
# 92 17 87
# 93 15 75
# 94 12 52
# 95 7 27
# ...
