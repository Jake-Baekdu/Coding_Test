# %% [markdown]
# # 문제 설명
#
# 요세푸스 문제는 다음과 같다.
#
# 1번부터 N번까지 N명의 사람이 원을 이루면서 앉아있고, 양의 정수 K(≤ N)가 주어진다. 이제 순서대로 K번째 사람을 제거한다. 한 사람이 제거되면 남은 사람들로 이루어진 원을 따라 이 과정을 계속해 나간다. 이 과정은 N명의 사람이 모두 제거될 때까지 계속된다. 원에서 사람들이 제거되는 순서를 (N, K)-요세푸스 순열이라고 한다. 예를 들어 (7, 3)-요세푸스 순열은 <3, 6, 2, 7, 5, 1, 4>이다.
#
# N과 K가 주어지면 (N, K)-요세푸스 순열을 구하는 프로그램을 작성하시오.
#
# ![image.png](attachment:image.png)

# %%
def solution(N, K):
    arr = [x for x in range(1,N+1)]
    print(arr)
    result = []
    i = K-1
    while True:
        result.append(arr.pop(i))
        if not arr:
            break;
        print(i, len(arr))
        i = (i+K-1)%len(arr)
        
    print(result)



solution(7,3)
# Out:
# [1, 2, 3, 4, 5, 6, 7]
# 2 6
# 4 5
# 1 4
# 3 3
# 2 2
# 0 1
# [3, 6, 2, 7, 5, 1, 4]

# %% [markdown]
# # 풀이 후기
#
# 처음에는 반복문을 만들때 어떤식으로 만들어야될까 고민이 많았다.
#
# 어차피 배열의 모든 수를 빼내야되니 무한루프를 돌리고 빠져나오는 조건으로 배열이 비었을 조건을 주면 완성이 된다. 이제 배열에서 pop으로 원소가 빠지면 배열의 위치가 조금씩 바뀌니 그 부분에 의한 것도 생각하면서 코딩을 해보았다.
#
# 백준은 생각보다 다른 풀이를 볼 수 있는 커뮤니티?같은 게 없어서 다른 코드를 보면서 공부할 시간이 없다. (구글링하면 나오긴하는데 가끔 틀린 것도 있어서 코드리뷰하다가 돌려보면 틀려서 가끔 허무할 때가 있어서 잘 안함...ㅇㅅㅇ)
